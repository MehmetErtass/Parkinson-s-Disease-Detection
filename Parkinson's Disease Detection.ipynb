# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
data= pd.read_csv("parkinsons.csv")

# %%
data.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
data.shape
# Out:
# (195, 24)

# %%
data.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
data.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
data['status'].value_counts()
# Out:
# 1    147
# 0     48
# Name: status, dtype: int64

# %%
data.groupby("status").mean()
# Out:
#         MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# status
# 0        181.937771    223.636750    145.207292        0.003866
# 1        145.180762    188.441463    106.893558        0.006989
#
#         MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# status
# 0               0.000023  0.001925  0.002056    0.005776      0.017615
# 1               0.000051  0.003757  0.003900    0.011273      0.033658
#
#         MDVP:Shimmer(dB)  ...  MDVP:APQ  Shimmer:DDA       NHR        HNR  \
# status                    ...
# 0               0.162958  ...  0.013305     0.028511  0.011483  24.678750
# 1               0.321204  ...  0.027600     0.053027  0.029211  20.974048
#
#             RPDE       DFA   spread1   spread2        D2       PPE
# status
# 0       0.442552  0.695716 -6.759264  0.160292  2.154491  0.123017
# 1       0.516816  0.725408 -5.333420  0.248133  2.456058  0.233828
#
# [2 rows x 22 columns]

# %%
X= data.drop(columns=['name','status'],axis=1)
Y=data['status']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y, test_size=0.2,random_state=10)

# %%
X_train
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 127      166.888       198.966        79.512         0.00638
# 185      116.286       177.291        96.983         0.00314
# 7        107.332       113.840       104.315         0.00290
# 26       171.041       208.313        75.501         0.00455
# 160      114.238       124.393        77.022         0.00581
# ..           ...           ...           ...             ...
# 113      210.141       232.706       185.258         0.00534
# 64       229.401       252.221       221.156         0.00205
# 15       142.167       217.455        83.159         0.00369
# 125      145.174       198.109        80.637         0.00733
# 9         95.056       120.103        91.226         0.00532
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 127          0.000040   0.00368   0.00351     0.01104       0.02857
# 185          0.000030   0.00134   0.00192     0.00403       0.01564
# ...

# %%
X_test
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 59       114.847       271.314       104.680         0.00867
# 5        120.552       131.162       113.787         0.00968
# 20       153.848       165.738        65.782         0.00840
# 121      176.824       215.293        83.961         0.00460
# 52       128.001       138.052       122.080         0.00436
# 19       156.405       189.398       142.822         0.00768
# 187      116.342       581.289        94.246         0.00267
# 55       109.860       126.358       104.437         0.00874
# 69       148.090       162.824        67.343         0.00762
# 2        116.682       131.111       111.555         0.01050
# 111      208.519       220.315       199.020         0.00609
# 10        88.333       112.240        84.072         0.00505
# 75       110.707       122.611       105.007         0.00516
# 132      119.056       125.213        86.795         0.00346
# ...

# %%
Y_train
# Out:
# 127    1
# 185    0
# 7      1
# 26     1
# 160    1
#       ..
# 113    1
# 64     0
# 15     1
# 125    1
# 9      1
# Name: status, Length: 156, dtype: int64

# %%
Y_test
# Out:
# 59     1
# 5      1
# 20     1
# 121    1
# 52     0
# 19     1
# 187    0
# 55     1
# 69     1
# 2      1
# 111    1
# 10     1
# 75     1
# 132    1
# 120    1
# 63     0
# 117    1
# 78     1
# 105    1
# 149    1
# 147    1
# 165    0
# 61     0
# 119    1
# 87     1
# 95     1
# 134    1
# 1      1
# 47     0
# 167    0
# 154    1
# 39     1
# 76     1
# 170    0
# 35     0
# 83     1
# 189    0
# 138    1
# 46     0
# Name: status, dtype: int64

# %%
scalar=StandardScaler()
scalar.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train=scalar.transform(X_train)
X_test=scalar.transform(X_test)

# %%
model=svm.SVC(kernel='linear')

# %%
model.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
train_accuracy_pred= model.predict(X_train)

# %%
accuracy=accuracy_score(Y_train,train_accuracy_pred)

# %%
accuracy
# Out:
# 0.8910256410256411

# %%
test_accuracy_pred= model.predict(X_test)
accuracy_test=accuracy_score(Y_test,test_accuracy_pred)

# %%
accuracy_test
# Out:
# 1.0

# %%
imput=[13.600,32.56000,26.127800,0.00480,0.00003,0.0023572,0.0034267,0.00696,
       0.0846137,0.373000,0.09252321,0.012591,0.047525,0.06062,0.01849,19.49300,0.629017,
       0.4698951,-5.186960,0.4237622,2.3557536,0.92589765]

# %%
input_converted= np.asarray(imput)

# %%
reshape= input_converted.reshape(1,-1)

# %%
standardize=scalar.transform(reshape)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
predict=model.predict(standardize)

# %%
predict
# Out:
# array([1], dtype=int64)

# %%
if (predict[0]==0):
    print("Person does not have Parkinson")
else:
     print("Person have Parkinson")
# Out:
# Person have Parkinson
